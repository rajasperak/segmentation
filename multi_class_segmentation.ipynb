# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder,OneHotEncoder,StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import RandomizedSearchCV,train_test_split,GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,auc
import xgboost as xgb
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
path = r'C:\Users\karl\Documents\datasets'
df_seg = pd.read_csv(r"C:\Users\karl\Documents\datasets\Segmentation.csv")
df_seg.head(10)
# Out:
#    CustomerID  Recency  Tenure  Frequency  MonetaryValue       Segment
# 0       12346      326     326          2           0.00  Fence Sitter
# 1       12349       19      19         73        1757.55     Potential
# 2       12350      310     310         17         334.40  Fence Sitter
# 3       12353      204     204          4          89.00  Fence Sitter
# 4       12354      232     232         58        1079.40  Fence Sitter
# 5       12355      214     214         13         459.40  Fence Sitter
# 6       12357       33      33        131        6207.67     Potential
# 7       12358        2     151         19        1168.06     Potential
# 8       12361      287     287         10         189.90  Fence Sitter
# 9       12364        8     112         85        1313.10     Potential

# %%
labels = df_seg.Segment.nunique()
labels
# Out:
# 3

# %%
df_seg["Segment"].value_counts(ascending=True)
# Out:
# Loyal            429
# Fence Sitter    1030
# Potential       1587
# Name: Segment, dtype: int64

# %%
df_seg["Segment"].value_counts(ascending=True,normalize=True)
# Out:
# Loyal           0.140840
# Fence Sitter    0.338148
# Potential       0.521011
# Name: Segment, dtype: float64

# %%
df_seg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3046 entries, 0 to 3045
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustomerID     3046 non-null   int64
#  1   Recency        3046 non-null   int64
#  2   Tenure         3046 non-null   int64
#  3   Frequency      3046 non-null   int64
#  4   MonetaryValue  3046 non-null   float64
#  5   Segment        3046 non-null   object
# dtypes: float64(1), int64(4), object(1)
# memory usage: 142.9+ KB

# %%
X = df_seg.drop(["CustomerID","Segment"],axis=1)
y = df_seg['Segment']
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=123,stratify=y)

# %%
ovr = OneVsRestClassifier(LogisticRegression(solver="lbfgs"))
ovr.fit(x_train,y_train)
# Out:
# OneVsRestClassifier(estimator=LogisticRegression())

# %%
def one_stat_result(model, x_train, y_train, x_test, y_test,b_seuil_label=False):
    train_predictions = model.predict(x_train.to_numpy())
    test_predictions = model.predict(x_test.to_numpy())
    if b_seuil_label==True:
        train_predictions = (train_predictions>=0.5).astype(int)
        test_predictions = (test_predictions>=0.5).astype(int)
    print("test_predictions:")
    print(test_predictions)
    cm = confusion_matrix(y_test, test_predictions)
    print(cm)
    print(">> resultat de la classification:")
    print(classification_report(y_test, test_predictions))
    TP = cm[0,0]
    TN = cm[1,1]
    FP = cm[0,1]
    FN = cm[1,0]
    classification_accuracy = (TP + TN) / float(TP + TN + FP + FN)
    print('Justesse de la Classification (accuracy) : {0:0.4f}'.format(classification_accuracy))
    classification_error = (FP + FN) / float(TP + TN + FP + FN)
    print('Erreurs de Classification : {0:0.4f}'.format(classification_error))
    recall = TP / float(TP + FN)
    print('Recall ou Sensitivity : {0:0.4f}'.format(recall))
    print("taux de faux positive:")
    false_positive_rate = FP / float(FP + TN)
    print(false_positive_rate)
    print('False Positive Rate : {0:0.4f}'.format(false_positive_rate))
    specificity = TN / (TN + FP)
    print('Specificity : {0:0.4f}'.format(specificity))

# %%
one_stat_result(ovr, x_train, y_train, x_test, y_test,b_seuil_label=False)
# Out:
# test_predictions:
# ['Potential' 'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter'
#  'Potential' 'Loyal' 'Potential' 'Potential' 'Fence Sitter' 'Fence Sitter'
#  'Potential' 'Loyal' 'Potential' 'Potential' 'Potential' 'Potential'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Potential' 'Fence Sitter'
#  'Potential' 'Potential' 'Potential' 'Fence Sitter' 'Potential'
#  'Fence Sitter' 'Potential' 'Potential' 'Potential' 'Potential' 'Loyal'
#  'Fence Sitter' 'Potential' 'Potential' 'Loyal' 'Fence Sitter' 'Potential'
#  'Potential' 'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Fence Sitter' 'Fence Sitter'
#  'Potential' 'Fence Sitter' 'Fence Sitter' 'Loyal' 'Potential'
#  'Fence Sitter' 'Potential' 'Fence Sitter' 'Fence Sitter' 'Potential'
#  'Potential' 'Potential' 'Potential' 'Fence Sitter' 'Potential'
#  'Potential' 'Potential' 'Loyal' 'Fence Sitter' 'Potential' 'Fence Sitter'
#  'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter' 'Loyal' 'Potential'
#  'Potential' 'Fence Sitter' 'Loyal' 'Potential' 'Potential' 'Fence Sitter'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Fence Sitter' 'Fence Sitter'
#  'Fence Sitter' 'Loyal' 'Loyal' 'Potential' 'Potential' 'Fence Sitter'
#  'Potential' 'Potential' 'Potential' 'Potential' 'Potential'
#  'Fence Sitter' 'Loyal' 'Potential' 'Potential' 'Potential' 'Fence Sitter'
#  'Fence Sitter' 'Potential' 'Fence Sitter' 'Fence Sitter' 'Potential'
#  'Potential' 'Fence Sitter' 'Fence Sitter' 'Fence Sitter' 'Fence Sitter'
#  'Fence Sitter' 'Potential' 'Fence Sitter' 'Potential' 'Loyal'
#  'Fence Sitter' 'Loyal' 'Potential' 'Potential' 'Potential' 'Loyal'
#  'Fence Sitter' 'Loyal' 'Loyal' 'Potential' 'Potential' 'Potential'
#  'Loyal' 'Potential' 'Potential' 'Potential' 'Fence Sitter' 'Fence Sitter'
#  'Potential' 'Potential' 'Fence Sitter' 'Fence Sitter' 'Potential'
#  'Potential' 'Loyal' 'Loyal' 'Potential' 'Potential' 'Potential'
#  'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter' 'Potential'
#  'Potential' 'Potential' 'Fence Sitter' 'Potential' 'Potential'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Potential' 'Potential'
#  'Potential' 'Potential' 'Loyal' 'Potential' 'Potential' 'Potential'
#  'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter' 'Potential'
#  'Fence Sitter' 'Potential' 'Fence Sitter' 'Loyal' 'Fence Sitter'
#  'Potential' 'Loyal' 'Fence Sitter' 'Fence Sitter' 'Potential' 'Potential'
#  'Potential' 'Loyal' 'Fence Sitter' 'Fence Sitter' 'Potential'
#  'Fence Sitter' 'Loyal' 'Loyal' 'Potential' 'Potential' 'Potential'
#  'Loyal' 'Fence Sitter' 'Potential' 'Potential' 'Potential' 'Fence Sitter'
#  'Fence Sitter' 'Potential' 'Loyal' 'Potential' 'Fence Sitter' 'Potential'
#  'Potential' 'Loyal' 'Loyal' 'Potential' 'Fence Sitter' 'Loyal'
#  'Potential' 'Potential' 'Potential' 'Fence Sitter' 'Fence Sitter'
#  'Potential' 'Potential' 'Potential' 'Potential' 'Potential' 'Potential'
#  'Potential' 'Potential' 'Fence Sitter' 'Fence Sitter' 'Potential'
#  'Fence Sitter' 'Fence Sitter' 'Loyal' 'Fence Sitter' 'Potential'
#  'Fence Sitter' 'Potential' 'Potential' 'Potential' 'Potential'
#  'Potential' 'Loyal' 'Potential' 'Potential' 'Potential' 'Fence Sitter'
#  'Potential' 'Fence Sitter' 'Potential' 'Loyal' 'Fence Sitter' 'Potential'
#  'Loyal' 'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter' 'Loyal'
#  'Potential' 'Potential' 'Potential' 'Fence Sitter' 'Fence Sitter' 'Loyal'
#  'Potential' 'Fence Sitter' 'Potential' 'Loyal' 'Fence Sitter' 'Potential'
#  'Fence Sitter' 'Fence Sitter' 'Fence Sitter' 'Fence Sitter' 'Potential'
#  'Fence Sitter' 'Potential' 'Fence Sitter' 'Loyal' 'Loyal' 'Potential'
#  'Potential' 'Fence Sitter' 'Fence Sitter' 'Potential' 'Potential'
#  'Potential' 'Potential' 'Potential' 'Potential' 'Potential' 'Potential'
#  'Potential' 'Potential' 'Potential' 'Potential' 'Potential' 'Potential'
#  'Loyal' 'Potential' 'Potential' 'Fence Sitter' 'Potential' 'Loyal'
#  'Fence Sitter' 'Potential' 'Fence Sitter' 'Loyal' 'Potential' 'Potential'
#  'Potential' 'Loyal' 'Potential' 'Potential' 'Fence Sitter' 'Potential'
#  'Potential' 'Fence Sitter' 'Potential' 'Loyal' 'Fence Sitter' 'Loyal'
#  'Fence Sitter' 'Potential' 'Loyal' 'Loyal' 'Potential' 'Fence Sitter'
#  'Loyal' 'Potential' 'Potential' 'Potential' 'Potential' 'Fence Sitter'
#  'Fence Sitter' 'Potential' 'Potential' 'Fence Sitter' 'Potential'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Potential' 'Loyal' 'Loyal'
#  'Potential' 'Potential' 'Fence Sitter' 'Potential' 'Potential'
#  'Potential' 'Potential' 'Potential' 'Potential' 'Loyal' 'Potential'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Potential' 'Potential'
#  'Potential' 'Fence Sitter' 'Fence Sitter' 'Loyal' 'Loyal' 'Potential'
#  'Fence Sitter' 'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter'
#  'Fence Sitter' 'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter'
#  'Potential' 'Loyal' 'Fence Sitter' 'Potential' 'Fence Sitter'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Fence Sitter' 'Potential'
#  'Potential' 'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter'
#  'Fence Sitter' 'Loyal' 'Loyal' 'Potential' 'Fence Sitter' 'Potential'
#  'Potential' 'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter'
#  'Potential' 'Potential' 'Potential' 'Loyal' 'Potential' 'Potential'
#  'Fence Sitter' 'Fence Sitter' 'Fence Sitter' 'Loyal' 'Fence Sitter'
#  'Potential' 'Potential' 'Potential' 'Potential' 'Fence Sitter' 'Loyal'
#  'Potential' 'Potential' 'Loyal' 'Potential' 'Potential' 'Potential'
#  'Fence Sitter' 'Fence Sitter' 'Fence Sitter' 'Fence Sitter'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Fence Sitter' 'Potential'
#  'Fence Sitter' 'Potential' 'Potential' 'Fence Sitter' 'Loyal' 'Loyal'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Potential' 'Fence Sitter'
#  'Potential' 'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter'
#  'Potential' 'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter'
#  'Potential' 'Fence Sitter' 'Fence Sitter' 'Potential' 'Potential'
#  'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter' 'Potential'
#  'Potential' 'Potential' 'Potential' 'Fence Sitter' 'Fence Sitter'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Fence Sitter' 'Loyal'
#  'Potential' 'Fence Sitter' 'Potential' 'Potential' 'Fence Sitter'
#  'Potential' 'Potential' 'Potential' 'Potential' 'Potential' 'Potential'
#  'Potential' 'Potential' 'Potential' 'Potential' 'Potential' 'Loyal'
#  'Fence Sitter' 'Potential' 'Potential' 'Fence Sitter' 'Fence Sitter'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Potential' 'Potential'
#  'Potential' 'Potential' 'Potential' 'Potential' 'Loyal' 'Potential'
#  'Fence Sitter' 'Potential' 'Potential' 'Fence Sitter' 'Fence Sitter'
#  'Fence Sitter' 'Loyal' 'Potential' 'Potential' 'Potential' 'Fence Sitter'
#  'Potential' 'Fence Sitter' 'Loyal' 'Fence Sitter' 'Loyal' 'Loyal'
#  'Potential' 'Potential' 'Fence Sitter' 'Potential' 'Potential'
#  'Fence Sitter' 'Potential' 'Fence Sitter' 'Potential' 'Potential'
#  'Potential' 'Fence Sitter' 'Fence Sitter' 'Potential' 'Fence Sitter'
#  'Fence Sitter' 'Loyal' 'Fence Sitter' 'Potential' 'Potential'
#  'Fence Sitter' 'Loyal' 'Loyal' 'Potential' 'Loyal' 'Potential'
#  'Fence Sitter' 'Potential' 'Potential' 'Fence Sitter' 'Potential'
#  'Potential' 'Potential' 'Potential' 'Fence Sitter' 'Fence Sitter'
#  'Fence Sitter' 'Potential' 'Potential' 'Potential' 'Loyal' 'Fence Sitter'
#  'Fence Sitter' 'Potential' 'Fence Sitter' 'Fence Sitter' 'Loyal'
#  'Potential' 'Fence Sitter' 'Potential' 'Loyal' 'Loyal' 'Potential'
#  'Fence Sitter' 'Fence Sitter' 'Fence Sitter' 'Fence Sitter' 'Potential'
#  'Loyal' 'Potential' 'Potential' 'Potential' 'Fence Sitter' 'Fence Sitter'
#  'Potential' 'Fence Sitter' 'Fence Sitter' 'Fence Sitter' 'Potential'
#  'Potential' 'Potential' 'Loyal' 'Fence Sitter' 'Potential' 'Fence Sitter'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Potential' 'Loyal' 'Potential'
#  'Fence Sitter' 'Potential' 'Potential']
# [[206   0   0]
#  [  3  80   3]
#  [  0   0 318]]
# >> resultat de la classification:
#               precision    recall  f1-score   support
#
# Fence Sitter       0.99      1.00      0.99       206
#        Loyal       1.00      0.93      0.96        86
#    Potential       0.99      1.00      1.00       318
#
#     accuracy                           0.99       610
#    macro avg       0.99      0.98      0.98       610
# weighted avg       0.99      0.99      0.99       610
#
# Justesse de la Classification (accuracy) : 0.9896
# Erreurs de Classification : 0.0104
# Recall ou Sensitivity : 0.9856
# taux de faux positive:
# 0.0
# False Positive Rate : 0.0000
# Specificity : 1.0000
# C:\Users\karl\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\karl\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\karl\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\karl\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\karl\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\karl\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
ovr2 = OneVsRestClassifier(LogisticRegression(solver="liblinear",penalty='l1'))
ovr2.fit(x_train,y_train)
one_stat_result(ovr2, x_train, y_train, x_test, y_test,b_seuil_label=False)
# Out:
# test_predictions:
# ['Potential' 'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter'
#  'Potential' 'Loyal' 'Potential' 'Potential' 'Fence Sitter' 'Fence Sitter'
#  'Potential' 'Loyal' 'Potential' 'Potential' 'Potential' 'Potential'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Potential' 'Fence Sitter'
#  'Potential' 'Potential' 'Potential' 'Fence Sitter' 'Potential'
#  'Fence Sitter' 'Potential' 'Potential' 'Potential' 'Potential' 'Loyal'
#  'Fence Sitter' 'Potential' 'Potential' 'Loyal' 'Fence Sitter' 'Potential'
#  'Potential' 'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Fence Sitter' 'Fence Sitter'
#  'Potential' 'Fence Sitter' 'Fence Sitter' 'Loyal' 'Potential'
#  'Fence Sitter' 'Potential' 'Fence Sitter' 'Fence Sitter' 'Potential'
#  'Potential' 'Potential' 'Potential' 'Fence Sitter' 'Potential'
#  'Potential' 'Potential' 'Loyal' 'Fence Sitter' 'Potential' 'Fence Sitter'
#  'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter' 'Loyal' 'Potential'
#  'Potential' 'Fence Sitter' 'Loyal' 'Potential' 'Potential' 'Fence Sitter'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Fence Sitter' 'Fence Sitter'
#  'Fence Sitter' 'Loyal' 'Loyal' 'Potential' 'Potential' 'Fence Sitter'
#  'Potential' 'Potential' 'Potential' 'Potential' 'Potential'
#  'Fence Sitter' 'Loyal' 'Potential' 'Potential' 'Potential' 'Fence Sitter'
#  'Fence Sitter' 'Potential' 'Fence Sitter' 'Fence Sitter' 'Potential'
#  'Potential' 'Fence Sitter' 'Fence Sitter' 'Fence Sitter' 'Fence Sitter'
#  'Fence Sitter' 'Potential' 'Fence Sitter' 'Potential' 'Loyal'
#  'Fence Sitter' 'Loyal' 'Potential' 'Potential' 'Potential' 'Loyal'
#  'Fence Sitter' 'Loyal' 'Loyal' 'Potential' 'Potential' 'Potential'
#  'Loyal' 'Potential' 'Potential' 'Potential' 'Fence Sitter' 'Fence Sitter'
#  'Potential' 'Potential' 'Fence Sitter' 'Fence Sitter' 'Potential'
#  'Potential' 'Loyal' 'Loyal' 'Potential' 'Potential' 'Potential'
#  'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter' 'Potential'
#  'Potential' 'Potential' 'Fence Sitter' 'Potential' 'Potential'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Potential' 'Potential'
#  'Potential' 'Potential' 'Loyal' 'Potential' 'Potential' 'Potential'
#  'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter' 'Potential'
#  'Fence Sitter' 'Potential' 'Fence Sitter' 'Loyal' 'Fence Sitter'
#  'Potential' 'Loyal' 'Fence Sitter' 'Fence Sitter' 'Potential' 'Potential'
#  'Potential' 'Loyal' 'Fence Sitter' 'Fence Sitter' 'Potential'
#  'Fence Sitter' 'Loyal' 'Loyal' 'Potential' 'Potential' 'Potential'
#  'Loyal' 'Fence Sitter' 'Potential' 'Potential' 'Potential' 'Fence Sitter'
#  'Fence Sitter' 'Potential' 'Loyal' 'Potential' 'Fence Sitter' 'Potential'
#  'Potential' 'Loyal' 'Loyal' 'Potential' 'Fence Sitter' 'Loyal'
#  'Potential' 'Potential' 'Potential' 'Fence Sitter' 'Fence Sitter'
#  'Potential' 'Potential' 'Potential' 'Potential' 'Potential' 'Potential'
#  'Potential' 'Potential' 'Fence Sitter' 'Fence Sitter' 'Potential'
#  'Fence Sitter' 'Fence Sitter' 'Loyal' 'Fence Sitter' 'Potential'
#  'Fence Sitter' 'Potential' 'Potential' 'Potential' 'Potential'
#  'Potential' 'Loyal' 'Potential' 'Potential' 'Potential' 'Fence Sitter'
#  'Potential' 'Fence Sitter' 'Potential' 'Loyal' 'Fence Sitter' 'Potential'
#  'Loyal' 'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter' 'Loyal'
#  'Potential' 'Potential' 'Potential' 'Fence Sitter' 'Fence Sitter' 'Loyal'
#  'Potential' 'Fence Sitter' 'Potential' 'Loyal' 'Fence Sitter' 'Potential'
#  'Fence Sitter' 'Fence Sitter' 'Fence Sitter' 'Fence Sitter' 'Potential'
#  'Fence Sitter' 'Potential' 'Fence Sitter' 'Loyal' 'Loyal' 'Potential'
#  'Potential' 'Fence Sitter' 'Fence Sitter' 'Potential' 'Potential'
#  'Potential' 'Potential' 'Potential' 'Potential' 'Potential' 'Potential'
#  'Potential' 'Potential' 'Potential' 'Potential' 'Potential' 'Potential'
#  'Loyal' 'Potential' 'Potential' 'Fence Sitter' 'Potential' 'Loyal'
#  'Fence Sitter' 'Potential' 'Fence Sitter' 'Loyal' 'Potential' 'Potential'
#  'Potential' 'Loyal' 'Potential' 'Potential' 'Fence Sitter' 'Potential'
#  'Potential' 'Fence Sitter' 'Potential' 'Loyal' 'Fence Sitter' 'Loyal'
#  'Fence Sitter' 'Potential' 'Loyal' 'Loyal' 'Potential' 'Fence Sitter'
#  'Loyal' 'Potential' 'Potential' 'Potential' 'Potential' 'Fence Sitter'
#  'Fence Sitter' 'Potential' 'Potential' 'Fence Sitter' 'Potential'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Potential' 'Loyal' 'Loyal'
#  'Potential' 'Potential' 'Fence Sitter' 'Potential' 'Potential'
#  'Potential' 'Potential' 'Potential' 'Potential' 'Loyal' 'Potential'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Potential' 'Potential'
#  'Potential' 'Fence Sitter' 'Fence Sitter' 'Loyal' 'Loyal' 'Potential'
#  'Fence Sitter' 'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter'
#  'Fence Sitter' 'Potential' 'Fence Sitter' 'Fence Sitter' 'Fence Sitter'
#  'Potential' 'Loyal' 'Fence Sitter' 'Potential' 'Fence Sitter'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Fence Sitter' 'Potential'
#  'Potential' 'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter'
#  'Fence Sitter' 'Loyal' 'Loyal' 'Potential' 'Fence Sitter' 'Potential'
#  'Potential' 'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter'
#  'Potential' 'Potential' 'Potential' 'Loyal' 'Potential' 'Potential'
#  'Fence Sitter' 'Loyal' 'Fence Sitter' 'Loyal' 'Fence Sitter' 'Potential'
#  'Potential' 'Potential' 'Potential' 'Fence Sitter' 'Loyal' 'Potential'
#  'Potential' 'Loyal' 'Potential' 'Potential' 'Potential' 'Fence Sitter'
#  'Fence Sitter' 'Fence Sitter' 'Fence Sitter' 'Fence Sitter'
#  'Fence Sitter' 'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter'
#  'Potential' 'Potential' 'Fence Sitter' 'Loyal' 'Loyal' 'Fence Sitter'
#  'Fence Sitter' 'Potential' 'Potential' 'Fence Sitter' 'Potential'
#  'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter' 'Potential'
#  'Potential' 'Fence Sitter' 'Potential' 'Fence Sitter' 'Potential'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Potential' 'Potential'
#  'Fence Sitter' 'Potential' 'Fence Sitter' 'Potential' 'Potential'
#  'Potential' 'Potential' 'Fence Sitter' 'Fence Sitter' 'Fence Sitter'
#  'Fence Sitter' 'Potential' 'Fence Sitter' 'Loyal' 'Potential'
#  'Fence Sitter' 'Potential' 'Potential' 'Fence Sitter' 'Potential'
#  'Potential' 'Potential' 'Potential' 'Potential' 'Potential' 'Potential'
#  'Potential' 'Potential' 'Potential' 'Potential' 'Loyal' 'Fence Sitter'
#  'Potential' 'Potential' 'Fence Sitter' 'Fence Sitter' 'Fence Sitter'
#  'Fence Sitter' 'Potential' 'Potential' 'Potential' 'Potential'
#  'Potential' 'Potential' 'Potential' 'Loyal' 'Potential' 'Fence Sitter'
#  'Potential' 'Potential' 'Fence Sitter' 'Fence Sitter' 'Fence Sitter'
#  'Loyal' 'Potential' 'Potential' 'Potential' 'Fence Sitter' 'Potential'
#  'Fence Sitter' 'Loyal' 'Fence Sitter' 'Loyal' 'Loyal' 'Potential'
#  'Potential' 'Fence Sitter' 'Potential' 'Potential' 'Fence Sitter'
#  'Potential' 'Fence Sitter' 'Potential' 'Potential' 'Potential'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Fence Sitter' 'Fence Sitter'
#  'Loyal' 'Fence Sitter' 'Potential' 'Potential' 'Fence Sitter' 'Loyal'
#  'Loyal' 'Potential' 'Loyal' 'Potential' 'Fence Sitter' 'Potential'
#  'Potential' 'Fence Sitter' 'Potential' 'Potential' 'Potential'
#  'Potential' 'Fence Sitter' 'Fence Sitter' 'Fence Sitter' 'Potential'
#  'Potential' 'Potential' 'Loyal' 'Fence Sitter' 'Fence Sitter' 'Potential'
#  'Fence Sitter' 'Fence Sitter' 'Loyal' 'Potential' 'Fence Sitter'
#  'Potential' 'Loyal' 'Loyal' 'Potential' 'Fence Sitter' 'Fence Sitter'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Loyal' 'Potential' 'Potential'
#  'Potential' 'Fence Sitter' 'Fence Sitter' 'Potential' 'Fence Sitter'
#  'Fence Sitter' 'Fence Sitter' 'Potential' 'Potential' 'Potential' 'Loyal'
#  'Fence Sitter' 'Potential' 'Fence Sitter' 'Fence Sitter' 'Fence Sitter'
#  'Potential' 'Potential' 'Loyal' 'Potential' 'Fence Sitter' 'Potential'
#  'Potential']
# [[206   0   0]
#  [  2  81   3]
#  [  1   0 317]]
# >> resultat de la classification:
#               precision    recall  f1-score   support
#
# Fence Sitter       0.99      1.00      0.99       206
#        Loyal       1.00      0.94      0.97        86
#    Potential       0.99      1.00      0.99       318
#
#     accuracy                           0.99       610
#    macro avg       0.99      0.98      0.99       610
# weighted avg       0.99      0.99      0.99       610
#
# Justesse de la Classification (accuracy) : 0.9931
# Erreurs de Classification : 0.0069
# Recall ou Sensitivity : 0.9904
# taux de faux positive:
# 0.0
# False Positive Rate : 0.0000
# Specificity : 1.0000
# C:\Users\karl\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\karl\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\karl\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\karl\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\karl\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\karl\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
